# %%
#Importing Libraries and Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel("Regional Sales Dataset.xlsx",sheet_name=None)

# %%
#Assign dataframes to each sheet
df_sales=df['Sales Orders']
df_customer=df['Customers']
df_products=df['Products']
df_regions=df['Regions']
df_state_reg=df['State Regions']
df_budgets=df['2017 Budgets']

# %%
print(df_sales.shape)
print(df_customer.shape)
print(df_products.shape)
print(df_regions.shape)
print(df_state_reg.shape)
print(df_budgets.shape)
# Out:
# (64104, 12)
# (175, 2)
# (30, 2)
# (994, 15)
# (49, 3)
# (30, 2)

# %%
df_sales.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost
# ...

# %%
df_customer.head()
# Out:
#    Customer Index Customer Names
# 0               1  Geiss Company
# 1               2  Jaxbean Group
# 2               3     Ascend Ltd
# 3               4      Eire Corp
# 4               5   Blogtags Ltd

# %%
df_products.head()
# Out:
#    Index Product Name
# 0      1    Product 1
# 1      2    Product 2
# 2      3    Product 3
# 3      4    Product 4
# 4      5    Product 5

# %%
df_regions.head()
# Out:
#    id        name                                   county state_code  \
# 0   1      Auburn                               Lee County         AL
# 1   2  Birmingham           Shelby County/Jefferson County         AL
# 2   3     Decatur           Limestone County/Morgan County         AL
# 3   4      Dothan  Dale County/Houston County/Henry County         AL
# 4   5      Hoover           Shelby County/Jefferson County         AL
#
#      state  type  latitude  longitude  area_code  population  households  \
# 0  Alabama  City  32.60986  -85.48078        334       62059       21767
# 1  Alabama  City  33.52744  -86.79905        205      212461       89972
# 2  Alabama  City  34.57332  -86.99214        256       55437       22294
# 3  Alabama  City  31.23370  -85.40682        334       68567       25913
# 4  Alabama  City  33.37695  -86.80558        205       84848       32789
#
#    median_income  land_area  water_area        time_zone
# ...

# %%
df_state_reg.head()
# Out:
#       Column1     Column2 Column3
# 0  State Code       State  Region
# 1          AL     Alabama   South
# 2          AR    Arkansas   South
# 3          AZ     Arizona    West
# 4          CA  California    West

# %%
df_budgets.head()
# Out:
#   Product Name  2017 Budgets
# 0    Product 1   3016489.209
# 1    Product 2   3050087.565
# 2    Product 3   2642352.432
# 3    Product 4   2885560.824
# 4    Product 5   3925424.542

# %%
new_header=df_state_reg.iloc[0]
df_state_reg=df_state_reg[1:]
df_state_reg.columns=new_header
df_state_reg.head()
# Out:
# 0 State Code       State Region
# 1         AL     Alabama  South
# 2         AR    Arkansas  South
# 3         AZ     Arizona   West
# 4         CA  California   West
# 5         CO    Colorado   West

# %%
df_sales.isnull().sum()
# Out:
# OrderNumber                  0
# OrderDate                    0
# Customer Name Index          0
# Channel                      0
# Currency Code                0
# Warehouse Code               0
# Delivery Region Index        0
# Product Description Index    0
# Order Quantity               0
# Unit Price                   0
# Line Total                   0
# Total Unit Cost              0
# dtype: int64

# %%
df_customer.isnull().sum()
# Out:
# Customer Index    0
# Customer Names    0
# dtype: int64

# %%
df_products.isnull().sum()
# Out:
# Index           0
# Product Name    0
# dtype: int64

# %%
df_regions.isnull().sum()
# Out:
# id               0
# name             0
# county           0
# state_code       0
# state            0
# type             0
# latitude         0
# longitude        0
# area_code        0
# population       0
# households       0
# median_income    0
# land_area        0
# water_area       0
# time_zone        0
# dtype: int64

# %%
df_state_reg.isnull().sum()
# Out:
# 0
# State Code    0
# State         0
# Region        0
# dtype: int64

# %%
df_budgets.isnull().sum()
# Out:
# Product Name    0
# 2017 Budgets    0
# dtype: int64

# %%
# Merge sales with customer dataset
df=df_sales.merge(df_customer,how='left',left_on='Customer Name Index',right_on='Customer Index')

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost  Customer Index  \
# ...

# %%
# Merge sales with product dataset
df=df.merge(df_products,how='left',left_on='Product Description Index',right_on='Index')

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost  Customer Index  \
# ...

# %%
# Merge sales with regions dataset
df=df.merge(df_regions,how='left',left_on='Delivery Region Index',right_on='id')

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  type  latitude  longitude area_code  \
# ...

# %%
# Merge sales with state region dataset
df=df.merge(df_state_reg[["State Code","Region"]],how='left',left_on='state_code',right_on='State Code')

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  longitude  area_code  population  \
# ...

# %%
# Merge sales with budgets dataset
df = df.merge(df_budgets,how='left',on='Product Name')

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  area_code  population  households  \
# ...

# %%
df.to_csv("Final Dataset.csv")

# %%
# Clean up redundant columns
cols_to_drop=['Customer Index','Index','id','State Code']
df=df.drop(columns=cols_to_drop,errors='ignore')
df.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  longitude  area_code population  \
# ...

# %%
#Convert all column names to lower case for easier access
df.columns=df.columns.str.lower()
df.head()
# Out:
#     ordernumber  orderdate  customer name index      channel currency code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   warehouse code  delivery region index  product description index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    order quantity  unit price  ...  longitude  area_code population  \
# ...

# %%
#Keep the important columns and delete the columns that we don't need
cols_to_keep = ['ordernumber','orderdate','customer names','channel','product name','order quantity','unit price','line total','total unit cost','state_code','state','region','latitude','longitude','2017 budgets']
df = df[cols_to_keep]
df.head()
# Out:
#     ordernumber  orderdate    customer names      channel product name  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
#
#    order quantity  unit price  line total  total unit cost state_code  \
# 0               6      2499.1     14994.6         1824.343         GA
# 1              11      2351.7     25868.7         1269.918         IN
# 2               6       978.2      5869.2          684.740         CA
# 3               7      2338.3     16368.1         1028.852         IN
# 4               8      2291.4     18331.2         1260.270         CT
#
#          state     region  latitude  longitude  2017 budgets
# ...

# %%
# Blank out budgets for non-2017 orders
df.loc[df['orderdate'].dt.year != 2017, 'budget'] = pd.NA
df.head()
# Out:
#     ordernumber  orderdate    customer names      channel product name  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
#
#    order quantity  unit price  line total  total unit cost state_code  \
# 0               6      2499.1     14994.6         1824.343         GA
# 1              11      2351.7     25868.7         1269.918         IN
# 2               6       978.2      5869.2          684.740         CA
# 3               7      2338.3     16368.1         1028.852         IN
# 4               8      2291.4     18331.2         1260.270         CT
#
#          state     region  latitude  longitude  2017 budgets budget
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64104 entries, 0 to 64103
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ordernumber      64104 non-null  object
#  1   orderdate        64104 non-null  datetime64[ns]
#  2   customer names   64104 non-null  object
#  3   channel          64104 non-null  object
#  4   product name     64104 non-null  object
#  5   order quantity   64104 non-null  int64
#  6   unit price       64104 non-null  float64
#  7   line total       64104 non-null  float64
#  8   total unit cost  64104 non-null  float64
#  9   state_code       64104 non-null  object
#  10  state            64104 non-null  object
#  11  region           64104 non-null  object
#  12  latitude         64104 non-null  float64
#  13  longitude        64104 non-null  float64
#  14  2017 budgets     64104 non-null  float64
#  15  budget           0 non-null      object
# ...

# %%
df.isnull().sum()
# Out:
# ordernumber            0
# orderdate              0
# customer names         0
# channel                0
# product name           0
# order quantity         0
# unit price             0
# line total             0
# total unit cost        0
# state_code             0
# state                  0
# region                 0
# latitude               0
# longitude              0
# 2017 budgets           0
# budget             64104
# dtype: int64

# %% [markdown]
# Feature Engineering

# %%
df['total_cost'] = df['order quantity'] * df['total unit cost']

# %%
df.head()
# Out:
#     ordernumber  orderdate    customer names      channel product name  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
#
#    order quantity  unit price  line total  total unit cost state_code  \
# 0               6      2499.1     14994.6         1824.343         GA
# 1              11      2351.7     25868.7         1269.918         IN
# 2               6       978.2      5869.2          684.740         CA
# 3               7      2338.3     16368.1         1028.852         IN
# 4               8      2291.4     18331.2         1260.270         CT
#
#          state     region  latitude  longitude  2017 budgets budget  \
# ...

# %%
df['profit'] = df['line total'] - df['total_cost']
df['profit_margin_pct'] = (df['profit'] / df['line total']) * 100

# %%
df.head()
# Out:
#     ordernumber  orderdate    customer names      channel product name  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
#
#    order quantity  unit price  line total  total unit cost state_code  \
# 0               6      2499.1     14994.6         1824.343         GA
# 1              11      2351.7     25868.7         1269.918         IN
# 2               6       978.2      5869.2          684.740         CA
# 3               7      2338.3     16368.1         1028.852         IN
# 4               8      2291.4     18331.2         1260.270         CT
#
#          state     region  latitude  longitude  2017 budgets budget  \
# ...

# %%
df['order_month_name'] = df['orderdate'].dt.month_name()
df['order_month_num'] = df['orderdate'].dt.month

# %%
df.head()
# Out:
#     ordernumber  orderdate    customer names      channel product name  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
#
#    order quantity  unit price  line total  total unit cost state_code  ...  \
# 0               6      2499.1     14994.6         1824.343         GA  ...
# 1              11      2351.7     25868.7         1269.918         IN  ...
# 2               6       978.2      5869.2          684.740         CA  ...
# 3               7      2338.3     16368.1         1028.852         IN  ...
# 4               8      2291.4     18331.2         1260.270         CT  ...
#
#       region  latitude  longitude  2017 budgets  budget total_cost     profit  \
# ...

# %%
df['order_month'] = df['orderdate'].dt.to_period('M')
monthly_sales = df.groupby('order_month')['line total'].sum()
df.head()
# Out:
#     ordernumber  orderdate    customer names      channel product name  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
#
#    order quantity  unit price  line total  total unit cost state_code  ...  \
# 0               6      2499.1     14994.6         1824.343         GA  ...
# 1              11      2351.7     25868.7         1269.918         IN  ...
# 2               6       978.2      5869.2          684.740         CA  ...
# 3               7      2338.3     16368.1         1028.852         IN  ...
# 4               8      2291.4     18331.2         1260.270         CT  ...
#
#    latitude  longitude  2017 budgets  budget  total_cost     profit  \
# ...

# %%
df
# Out:
#         ordernumber  orderdate    customer names      channel product name  \
# 0       SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale   Product 27
# 1      SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor   Product 20
# 2      SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale   Product 26
# 3      SO - 0005614 2014-01-01  Colgate-Pa Group       Export    Product 7
# 4      SO - 0005781 2014-01-01     Deseret Group    Wholesale    Product 8
# ...             ...        ...               ...          ...          ...
# 64099  SO - 0007573 2018-02-28   Dazzlesphe Corp    Wholesale   Product 26
# 64100  SO - 0007706 2018-02-28        Yombu Corp       Export   Product 21
# 64101  SO - 0007718 2018-02-28        Bath Group  Distributor   Product 13
# 64102  SO - 0008084 2018-02-28     Linklinks Ltd  Distributor   Product 20
# 64103  SO - 0008654 2018-02-28       SAFEWAY Ltd  Distributor   Product 15
#
# ...

# %%
df.to_csv('Sales_data.csv', index=False)
